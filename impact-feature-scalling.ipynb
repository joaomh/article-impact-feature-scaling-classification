# %% [markdown]
# # Impact of Feature Scaling in Machine Learning Algorithms
#
# An overview of the impact of feature scaling in MLs algorithms

# %%
import pandas as pd
import numpy as np
# import the datasets from UCI
from ucimlrepo import fetch_ucirepo   
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)
breast_cancer_wisconsin_original = fetch_ucirepo(id=15)
dry_bean_dataset = fetch_ucirepo(id=602)
glass_identification = fetch_ucirepo(id=42) 
heart_disease = fetch_ucirepo(id=45)
hepatitis = fetch_ucirepo(id=46)
iris = fetch_ucirepo(id=53)
letter_recognition = fetch_ucirepo(id=59) 
lung_cancer = fetch_ucirepo(id=62)
magic_gamma_telescope = fetch_ucirepo(id=159) 
parkinsons = fetch_ucirepo(id=174) 
rice_cammeo_and_osmancik = fetch_ucirepo(id=545)
wine = fetch_ucirepo(id=109)

# %%
dataset_list = [
    'breast_cancer_wisconsin_diagnostic',
    'breast_cancer_wisconsin_original',
    'dry_bean_dataset',
    'glass_identification',
    'heart_disease',
    'hepatitis',
    'iris',
    'letter_recognition',
    'magic_gamma_telescope',
    'parkinsons',
    'rice_cammeo_and_osmancik',
    'wine'
    ]

# %%
# convert into dataframe for some analysis and other conversion
df_breast_cancer_wisconsin_diagnostic = breast_cancer_wisconsin_diagnostic.data.features.join(breast_cancer_wisconsin_diagnostic.data.targets)
df_breast_cancer_wisconsin_original = breast_cancer_wisconsin_original.data.features.join(breast_cancer_wisconsin_original.data.targets)
df_dry_bean_dataset = dry_bean_dataset.data.features.join(dry_bean_dataset.data.targets)
df_glass_identification = glass_identification.data.features.join(glass_identification.data.targets)
df_heart_disease = heart_disease.data.features.join(heart_disease.data.targets)
df_hepatitis = hepatitis.data.features.join(hepatitis.data.targets)
df_iris = iris.data.features.join(iris.data.targets)
df_letter_recognition = letter_recognition.data.features.join(letter_recognition.data.targets)
df_lung_cancer = lung_cancer.data.features.join(lung_cancer.data.targets)
df_magic_gamma_telescope = magic_gamma_telescope.data.features.join(magic_gamma_telescope.data.targets)
df_parkinsons = parkinsons.data.features.join(parkinsons.data.targets)
df_rice_cammeo_and_osmancik = rice_cammeo_and_osmancik.data.features.join(rice_cammeo_and_osmancik.data.targets)
df_wine = wine.data.features.join(wine.data.targets)

# %% [markdown]
# ## Analysis if all the feature are non-null and numeric type

# %%
df_breast_cancer_wisconsin_diagnostic.info()
df_breast_cancer_wisconsin_original.info()
df_dry_bean_dataset.info()
df_glass_identification.info()
df_heart_disease.info()
df_hepatitis.info()
df_iris.info()
df_letter_recognition.info()
df_lung_cancer.info()
df_magic_gamma_telescope.info()
df_parkinsons.info()
df_rice_cammeo_and_osmancik.info()
df_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             569 non-null    float64
#  1   texture1            569 non-null    float64
#  2   perimeter1          569 non-null    float64
#  3   area1               569 non-null    float64
#  4   smoothness1         569 non-null    float64
#  5   compactness1        569 non-null    float64
#  6   concavity1          569 non-null    float64
#  7   concave_points1     569 non-null    float64
#  8   symmetry1           569 non-null    float64
#  9   fractal_dimension1  569 non-null    float64
#  10  radius2             569 non-null    float64
#  11  texture2            569 non-null    float64
#  12  perimeter2          569 non-null    float64
#  13  area2               569 non-null    float64
#  14  smoothness2         569 non-null    float64
#  15  compactness2        569 non-null    float64
#  16  concavity2          569 non-null    float64
#  17  concave_points2     569 non-null    float64
#  18  symmetry2           569 non-null    float64
#  19  fractal_dimension2  569 non-null    float64
#  20  radius3             569 non-null    float64
#  21  texture3            569 non-null    float64
#  22  perimeter3          569 non-null    float64
#  23  area3               569 non-null    float64
#  24  smoothness3         569 non-null    float64
#  25  compactness3        569 non-null    float64
#  26  concavity3          569 non-null    float64
#  27  concave_points3     569 non-null    float64
#  28  symmetry3           569 non-null    float64
#  29  fractal_dimension3  569 non-null    float64
#  30  Diagnosis           569 non-null    object
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump_thickness              699 non-null    int64
#  1   Uniformity_of_cell_size      699 non-null    int64
#  2   Uniformity_of_cell_shape     699 non-null    int64
#  3   Marginal_adhesion            699 non-null    int64
#  4   Single_epithelial_cell_size  699 non-null    int64
#  5   Bare_nuclei                  683 non-null    float64
#  6   Bland_chromatin              699 non-null    int64
#  7   Normal_nucleoli              699 non-null    int64
#  8   Mitoses                      699 non-null    int64
#  9   Class                        699 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 54.7 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRatio      13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  Roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RI             214 non-null    float64
#  1   Na             214 non-null    float64
#  2   Mg             214 non-null    float64
#  3   Al             214 non-null    float64
#  4   Si             214 non-null    float64
#  5   K              214 non-null    float64
#  6   Ca             214 non-null    float64
#  7   Ba             214 non-null    float64
#  8   Fe             214 non-null    float64
#  9   Type_of_glass  214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              155 non-null    int64
#  1   Sex              155 non-null    int64
#  2   Steroid          154 non-null    float64
#  3   Antivirals       155 non-null    int64
#  4   Fatigue          154 non-null    float64
#  5   Malaise          154 non-null    float64
#  6   Anorexia         154 non-null    float64
#  7   Liver Big        145 non-null    float64
#  8   Liver Firm       144 non-null    float64
#  9   Spleen Palpable  150 non-null    float64
#  10  Spiders          150 non-null    float64
#  11  Ascites          150 non-null    float64
#  12  Varices          150 non-null    float64
#  13  Bilirubin        149 non-null    float64
#  14  Alk Phosphate    126 non-null    float64
#  15  Sgot             151 non-null    float64
#  16  Albumin          139 non-null    float64
#  17  Protime          88 non-null     float64
#  18  Histology        155 non-null    int64
#  19  Class            155 non-null    int64
# dtypes: float64(15), int64(5)
# memory usage: 24.3 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x-box   20000 non-null  int64
#  1   y-box   20000 non-null  int64
#  2   width   20000 non-null  int64
#  3   high    20000 non-null  int64
#  4   onpix   20000 non-null  int64
#  5   x-bar   20000 non-null  int64
#  6   y-bar   20000 non-null  int64
#  7   x2bar   20000 non-null  int64
#  8   y2bar   20000 non-null  int64
#  9   xybar   20000 non-null  int64
#  10  x2ybr   20000 non-null  int64
#  11  xy2br   20000 non-null  int64
#  12  x-ege   20000 non-null  int64
#  13  xegvy   20000 non-null  int64
#  14  y-ege   20000 non-null  int64
#  15  yegvx   20000 non-null  int64
#  16  lettr   20000 non-null  object
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 57 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Attribute1   32 non-null     int64
#  1   Attribute2   32 non-null     int64
#  2   Attribute3   32 non-null     int64
#  3   Attribute4   28 non-null     float64
#  4   Attribute5   32 non-null     int64
#  5   Attribute6   32 non-null     int64
#  6   Attribute7   32 non-null     int64
#  7   Attribute8   32 non-null     int64
#  8   Attribute9   32 non-null     int64
#  9   Attribute10  32 non-null     int64
#  10  Attribute11  32 non-null     int64
#  11  Attribute12  32 non-null     int64
#  12  Attribute13  32 non-null     int64
#  13  Attribute14  32 non-null     int64
#  14  Attribute15  32 non-null     int64
#  15  Attribute16  32 non-null     int64
#  16  Attribute17  32 non-null     int64
#  17  Attribute18  32 non-null     int64
#  18  Attribute19  32 non-null     int64
#  19  Attribute20  32 non-null     int64
#  20  Attribute21  32 non-null     int64
#  21  Attribute22  32 non-null     int64
#  22  Attribute23  32 non-null     int64
#  23  Attribute24  32 non-null     int64
#  24  Attribute25  32 non-null     int64
#  25  Attribute26  32 non-null     int64
#  26  Attribute27  32 non-null     int64
#  27  Attribute28  32 non-null     int64
#  28  Attribute29  32 non-null     int64
#  29  Attribute30  32 non-null     int64
#  30  Attribute31  32 non-null     int64
#  31  Attribute32  32 non-null     int64
#  32  Attribute33  32 non-null     int64
#  33  Attribute34  32 non-null     int64
#  34  Attribute35  32 non-null     int64
#  35  Attribute36  32 non-null     int64
#  36  Attribute37  32 non-null     int64
#  37  Attribute38  31 non-null     float64
#  38  Attribute39  32 non-null     int64
#  39  Attribute40  32 non-null     int64
#  40  Attribute41  32 non-null     int64
#  41  Attribute42  32 non-null     int64
#  42  Attribute43  32 non-null     int64
#  43  Attribute44  32 non-null     int64
#  44  Attribute45  32 non-null     int64
#  45  Attribute46  32 non-null     int64
#  46  Attribute47  32 non-null     int64
#  47  Attribute48  32 non-null     int64
#  48  Attribute49  32 non-null     int64
#  49  Attribute50  32 non-null     int64
#  50  Attribute51  32 non-null     int64
#  51  Attribute52  32 non-null     int64
#  52  Attribute53  32 non-null     int64
#  53  Attribute54  32 non-null     int64
#  54  Attribute55  32 non-null     int64
#  55  Attribute56  32 non-null     int64
#  56  class        32 non-null     int64
# dtypes: float64(2), int64(55)
# memory usage: 14.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   19020 non-null  float64
#  1   fWidth    19020 non-null  float64
#  2   fSize     19020 non-null  float64
#  3   fConc     19020 non-null  float64
#  4   fConc1    19020 non-null  float64
#  5   fAsym     19020 non-null  float64
#  6   fM3Long   19020 non-null  float64
#  7   fM3Trans  19020 non-null  float64
#  8   fAlpha    19020 non-null  float64
#  9   fDist     19020 non-null  float64
#  10  class     19020 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 1.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MDVP:Fo       195 non-null    float64
#  1   MDVP:Fhi      195 non-null    float64
#  2   MDVP:Flo      195 non-null    float64
#  3   MDVP:Jitter   195 non-null    float64
#  4   MDVP:Jitter   195 non-null    float64
#  5   MDVP:RAP      195 non-null    float64
#  6   MDVP:PPQ      195 non-null    float64
#  7   Jitter:DDP    195 non-null    float64
#  8   MDVP:Shimmer  195 non-null    float64
#  9   MDVP:Shimmer  195 non-null    float64
#  10  Shimmer:APQ3  195 non-null    float64
#  11  Shimmer:APQ5  195 non-null    float64
#  12  MDVP:APQ      195 non-null    float64
#  13  Shimmer:DDA   195 non-null    float64
#  14  NHR           195 non-null    float64
#  15  HNR           195 non-null    float64
#  16  RPDE          195 non-null    float64
#  17  DFA           195 non-null    float64
#  18  spread1       195 non-null    float64
#  19  spread2       195 non-null    float64
#  20  D2            195 non-null    float64
#  21  PPE           195 non-null    float64
#  22  status        195 non-null    int64
# dtypes: float64(22), int64(1)
# memory usage: 35.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3810 entries, 0 to 3809
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               3810 non-null   int64
#  1   Perimeter          3810 non-null   float64
#  2   Major_Axis_Length  3810 non-null   float64
#  3   Minor_Axis_Length  3810 non-null   float64
#  4   Eccentricity       3810 non-null   float64
#  5   Convex_Area        3810 non-null   int64
#  6   Extent             3810 non-null   float64
#  7   Class              3810 non-null   object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 238.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    float64
#  1   Malicacid                     178 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity_of_ash             178 non-null    float64
#  4   Magnesium                     178 non-null    int64
#  5   Total_phenols                 178 non-null    float64
#  6   Flavanoids                    178 non-null    float64
#  7   Nonflavanoid_phenols          178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color_intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  0D280_0D315_of_diluted_wines  178 non-null    float64
#  12  Proline                       178 non-null    int64
#  13  class                         178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df_breast_cancer_wisconsin_original = df_breast_cancer_wisconsin_original.fillna(0)
df_lung_cancer = df_lung_cancer.fillna(0)

# %% [markdown]
# ## Train and test split

# %%
from sklearn.model_selection import train_test_split
for i in dataset_list:
    exec('X_train_{}, X_test_{}, y_train_{}, y_test_{} = train_test_split({}.data.features, {}.data.targets, test_size=0.3, random_state=0)'.format(i,i,i,i,i,i))

# %% [markdown]
# ## Scaling Methods

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler, RobustScaler
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
scaling_list = [
    'MinMaxScaler',
    'MaxAbsScaler',
    'StandardScaler',
    'ParetoScaling',
    'StandardStabilityScaling',
    'MeanCentered',
    'MedianAbsScaler',
    'RobustScaler',
    'PowerTransformer',
    'QuantileTransformer',
    'DecimalScaling',
    'TanhTransformer',
    'LogisticSigmoidTransformer',
    'HyperbolicTangentTransformer'
]

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from typing import List

class MeanCentered(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.means_ = {col: np.mean(X[col]) for col in self.cols}
        self.stds_ = {col: np.std(X[col]) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = (X[col] - self.means_[col])
        return X
    
class MedianAbsScaler(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.median_ = {col: np.median(X[col]) for col in self.cols}
        self.mad_ = {col: np.median(np.absolute(X[col]-np.median(X[col]))) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = (X[col] - self.median_[col]) / self.mad_[col]
        return X
    
class StandardStabilityScaling(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.means_ = {col: np.mean(X[col]) for col in self.cols}
        self.stds_ = {col: np.std(X[col]) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = ((X[col] - self.means_[col]) / self.stds_[col])*(self.means_[col]/self.stds_[col])
        return X
    
class ParetoScaling(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.means_ = {col: np.mean(X[col]) for col in self.cols}
        self.stds_ = {col: np.std(X[col]) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = (X[col] - self.means_[col]) / np.sqrt(self.stds_[col])
        return X
    
class DecimalScaling(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.len_ = {col: len(str(abs(np.max((X[col]))))) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = X[col] / 10**self.len_[col]
        return X

class TanhTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.means_ = {col: np.mean(X[col]) for col in self.cols}
        self.stds_ = {col: np.std(X[col]) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = 0.5*(np.tanh(0.01*((X[col] - self.means_[col])/ self.stds_[col])) + 1)
        return X

class LogisticSigmoidTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.means_ = {col: np.mean(X[col]) for col in self.cols}
        self.stds_ = {col: np.std(X[col]) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = 1 /(1 + np.exp(-(X[col] - self.means_[col]) / self.stds_[col]))
        return X
    
class HyperbolicTangentTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cols: List[str]):
        self.cols = cols

    def fit(self, X: pd.DataFrame, y: pd.Series = None):
        self.means_ = {col: np.mean(X[col]) for col in self.cols}
        self.stds_ = {col: np.std(X[col]) for col in self.cols}
        return self

    def transform(self, X: pd.DataFrame):
        X = X.copy()
        for col in self.cols:
            X[col] = ((1 - np.exp(-(X[col] - self.means_[col]) / self.stds_[col]))) / (1 + np.exp(-(X[col] - self.means_[col]) / self.stds_[col]))
        return X

# %%
from sklearn.model_selection import train_test_split
for i in dataset_list:
    exec('X_train_{}, X_test_{}, y_train_{}, y_test_{} = train_test_split({}.data.features, {}.data.targets, test_size=0.3, random_state=0)'.format(i,i,i,i,i,i))
    exec('X_train_{} = X_train_{}.fillna(0)'.format(i,i))
    exec('X_test_{} = X_test_{}.fillna(0)'.format(i,i))
    exec('y_train_{} = y_train_{}.fillna(0)'.format(i,i))
    exec('y_test_{} = y_test_{}.fillna(0)'.format(i,i))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %%
# prepare models
models = []
# models.append(('LR', LogisticRegression(random_state=0)))
models.append(('SVM', SVC(kernel='linear')))
models.append(('MLP', MLPClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('NB', GaussianNB()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('Ada', AdaBoostClassifier()))
models.append(('XGB', XGBClassifier()))
models.append(('CatBoost', CatBoostClassifier()))
models.append(('LGBM', LGBMClassifier()))

# %%
from sklearn.metrics import accuracy_score
results = []
for name, model in models:
    for scaling in scaling_list:
        for i in dataset_list:
            if scaling in ['MinMaxScaler','MaxAbsScaler','StandardScaler','RobustScaler','PowerTransformer','QuantileTransformer']:
                exec('scaler = {}()'.format(scaling))
                exec('scaler.fit(X_train_{})'.format(i))
                exec('scaler.transform(X_test_{})'.format(i))
                exec('clf = {}'.format(model))
                exec('clf.fit(X_train_{}, y_train_{}.values.ravel())'.format(i,i))
                exec('y_pred=clf.predict(X_test_{})'.format(i))
                exec('accuracy=accuracy_score(y_pred, y_test_{}.values.ravel())'.format(i))
                a = scaling
                b = i
                exec('results.append([accuracy,{},a,b])'.format(model))
            else:
                exec('scaler = {}(cols=X_train_{}.columns)'.format(scaling,i))
                exec('scaler.fit_transform(X_train_{})'.format(i))
                exec('scaler.transform(X_test_{})'.format(i))
                exec('clf = {}'.format(model))
                exec('clf.fit(X_train_{}, y_train_{}.values.ravel())'.format(i,i))
                exec('y_pred=clf.predict(X_test_{})'.format(i))
                exec('accuracy=accuracy_score(y_pred, y_test_{}.values.ravel())'.format(i))
                
                # i didin't find any other way to save scaling method and name of data inste into results
                a = scaling
                b = i
                exec('results.append([accuracy,{},a,b])'.format(model))
# Out:
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (489). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (149). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (212). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (105). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (136). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (124). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (489). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (149). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (212). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (105). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (136). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (124). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (489). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (149). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (212). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (105). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (136). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (124). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (489). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (149). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (212). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (105). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (136). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (124). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (489). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (149). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (212). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (105). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (136). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (124). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (489). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (149). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (212). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (105). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (136). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (124). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /home/joao/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Traceback (most recent call last):
#
#   File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 10
#     exec('clf = {}'.format(model))
#
#   File <string>:11
#     predictor=None, random_state=None, ...)
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
results
# Out:
# [[0.9590643274853801,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'MinMaxScaler', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'MinMaxScaler', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'MinMaxScaler', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'MinMaxScaler', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'MinMaxScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'MinMaxScaler', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'MaxAbsScaler', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'MaxAbsScaler', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'MaxAbsScaler', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'MaxAbsScaler', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'MaxAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'MaxAbsScaler', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'StandardScaler', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'StandardScaler', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'StandardScaler', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'StandardScaler', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'StandardScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'StandardScaler', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'ParetoScaling', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'ParetoScaling', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'ParetoScaling', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'ParetoScaling', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'ParetoScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'ParetoScaling', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'heart_disease'],
#  [0.7872340425531915,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'hepatitis'],
#  [0.9777777777777777,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815,
#   SVC(kernel='linear'),
#   'StandardStabilityScaling',
#   'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'MeanCentered', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'MeanCentered', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'MeanCentered', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'MeanCentered', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'MeanCentered',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'MeanCentered', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'MedianAbsScaler', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'MedianAbsScaler', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'MedianAbsScaler', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'MedianAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'MedianAbsScaler', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'RobustScaler', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'RobustScaler', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'RobustScaler', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'RobustScaler', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'RobustScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'RobustScaler', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'PowerTransformer', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'PowerTransformer', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'PowerTransformer', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'PowerTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'PowerTransformer', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'heart_disease'],
#  [0.7872340425531915,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'QuantileTransformer', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'QuantileTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'QuantileTransformer', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'glass_identification'],
#  [0.5714285714285714, SVC(kernel='linear'), 'DecimalScaling', 'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'DecimalScaling', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'DecimalScaling', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'DecimalScaling', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'DecimalScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'DecimalScaling', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'heart_disease'],
#  [0.7872340425531915, SVC(kernel='linear'), 'TanhTransformer', 'hepatitis'],
#  [0.9777777777777777, SVC(kernel='linear'), 'TanhTransformer', 'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, SVC(kernel='linear'), 'TanhTransformer', 'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'TanhTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, SVC(kernel='linear'), 'TanhTransformer', 'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'heart_disease'],
#  [0.7872340425531915,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'hepatitis'],
#  [0.9777777777777777,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815,
#   SVC(kernel='linear'),
#   'LogisticSigmoidTransformer',
#   'wine'],
#  [0.9590643274853801,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9169931439764937,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'dry_bean_dataset'],
#  [0.5692307692307692,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'heart_disease'],
#  [0.7872340425531915,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'hepatitis'],
#  [0.9777777777777777,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'iris'],
#  [0.8611666666666666,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'letter_recognition'],
#  [0.7919733613739923,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'parkinsons'],
#  [0.9378827646544182,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815,
#   SVC(kernel='linear'),
#   'HyperbolicTangentTransformer',
#   'wine'],
#  [0.935672514619883,
#   MLPClassifier(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.4691478942213516, MLPClassifier(), 'MinMaxScaler', 'dry_bean_dataset'],
#  [0.5692307692307692, MLPClassifier(), 'MinMaxScaler', 'glass_identification'],
#  [0.5274725274725275, MLPClassifier(), 'MinMaxScaler', 'heart_disease'],
#  [0.8297872340425532, MLPClassifier(), 'MinMaxScaler', 'hepatitis'],
#  [0.9333333333333333, MLPClassifier(), 'MinMaxScaler', 'iris'],
#  [0.9238333333333333, MLPClassifier(), 'MinMaxScaler', 'letter_recognition'],
#  [0.8271994391868209,
#   MLPClassifier(),
#   'MinMaxScaler',
#   'magic_gamma_telescope'],
#  [0.8813559322033898, MLPClassifier(), 'MinMaxScaler', 'parkinsons'],
#  [0.5660542432195975,
#   MLPClassifier(),
#   'MinMaxScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9444444444444444, MLPClassifier(), 'MinMaxScaler', 'wine'],
#  [0.9239766081871345,
#   MLPClassifier(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.36679725759059745, MLPClassifier(), 'MaxAbsScaler', 'dry_bean_dataset'],
#  [0.4, MLPClassifier(), 'MaxAbsScaler', 'glass_identification'],
#  [0.26373626373626374, MLPClassifier(), 'MaxAbsScaler', 'heart_disease'],
#  [0.723404255319149, MLPClassifier(), 'MaxAbsScaler', 'hepatitis'],
#  [0.9333333333333333, MLPClassifier(), 'MaxAbsScaler', 'iris'],
#  [0.9233333333333333, MLPClassifier(), 'MaxAbsScaler', 'letter_recognition'],
#  [0.8305292674377848,
#   MLPClassifier(),
#   'MaxAbsScaler',
#   'magic_gamma_telescope'],
#  [0.8813559322033898, MLPClassifier(), 'MaxAbsScaler', 'parkinsons'],
#  [0.5660542432195975,
#   MLPClassifier(),
#   'MaxAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9444444444444444, MLPClassifier(), 'MaxAbsScaler', 'wine'],
#  [0.9122807017543859,
#   MLPClassifier(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.279382957884427, MLPClassifier(), 'StandardScaler', 'dry_bean_dataset'],
#  [0.5230769230769231,
#   MLPClassifier(),
#   'StandardScaler',
#   'glass_identification'],
#  [0.5494505494505495, MLPClassifier(), 'StandardScaler', 'heart_disease'],
#  [0.7659574468085106, MLPClassifier(), 'StandardScaler', 'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'StandardScaler', 'iris'],
#  [0.923, MLPClassifier(), 'StandardScaler', 'letter_recognition'],
#  [0.8345601121626358,
#   MLPClassifier(),
#   'StandardScaler',
#   'magic_gamma_telescope'],
#  [0.8813559322033898, MLPClassifier(), 'StandardScaler', 'parkinsons'],
#  [0.42869641294838146,
#   MLPClassifier(),
#   'StandardScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9074074074074074, MLPClassifier(), 'StandardScaler', 'wine'],
#  [0.9473684210526315,
#   MLPClassifier(),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.5019588638589618, MLPClassifier(), 'ParetoScaling', 'dry_bean_dataset'],
#  [0.5230769230769231,
#   MLPClassifier(),
#   'ParetoScaling',
#   'glass_identification'],
#  [0.5054945054945055, MLPClassifier(), 'ParetoScaling', 'heart_disease'],
#  [0.7659574468085106, MLPClassifier(), 'ParetoScaling', 'hepatitis'],
#  [0.9333333333333333, MLPClassifier(), 'ParetoScaling', 'iris'],
#  [0.9153333333333333, MLPClassifier(), 'ParetoScaling', 'letter_recognition'],
#  [0.8326323168594462,
#   MLPClassifier(),
#   'ParetoScaling',
#   'magic_gamma_telescope'],
#  [0.7796610169491526, MLPClassifier(), 'ParetoScaling', 'parkinsons'],
#  [0.573928258967629,
#   MLPClassifier(),
#   'ParetoScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.42592592592592593, MLPClassifier(), 'ParetoScaling', 'wine'],
#  [0.9649122807017544,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.1665034280117532,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'dry_bean_dataset'],
#  [0.4461538461538462,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'glass_identification'],
#  [0.5384615384615384,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'heart_disease'],
#  [0.851063829787234, MLPClassifier(), 'StandardStabilityScaling', 'hepatitis'],
#  [0.9333333333333333, MLPClassifier(), 'StandardStabilityScaling', 'iris'],
#  [0.9216666666666666,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'letter_recognition'],
#  [0.8364879074658255,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'magic_gamma_telescope'],
#  [0.8813559322033898,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'parkinsons'],
#  [0.6929133858267716,
#   MLPClassifier(),
#   'StandardStabilityScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.5185185185185185, MLPClassifier(), 'StandardStabilityScaling', 'wine'],
#  [0.9473684210526315,
#   MLPClassifier(),
#   'MeanCentered',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   MLPClassifier(),
#   'MeanCentered',
#   'breast_cancer_wisconsin_original'],
#  [0.5320763956904995, MLPClassifier(), 'MeanCentered', 'dry_bean_dataset'],
#  [0.3230769230769231, MLPClassifier(), 'MeanCentered', 'glass_identification'],
#  [0.4725274725274725, MLPClassifier(), 'MeanCentered', 'heart_disease'],
#  [0.8085106382978723, MLPClassifier(), 'MeanCentered', 'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'MeanCentered', 'iris'],
#  [0.9155, MLPClassifier(), 'MeanCentered', 'letter_recognition'],
#  [0.8399929898352612,
#   MLPClassifier(),
#   'MeanCentered',
#   'magic_gamma_telescope'],
#  [0.864406779661017, MLPClassifier(), 'MeanCentered', 'parkinsons'],
#  [0.5756780402449694,
#   MLPClassifier(),
#   'MeanCentered',
#   'rice_cammeo_and_osmancik'],
#  [0.4074074074074074, MLPClassifier(), 'MeanCentered', 'wine'],
#  [0.9473684210526315,
#   MLPClassifier(),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9428571428571428,
#   MLPClassifier(),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.29921645445641526, MLPClassifier(), 'MedianAbsScaler', 'dry_bean_dataset'],
#  [0.5230769230769231,
#   MLPClassifier(),
#   'MedianAbsScaler',
#   'glass_identification'],
#  [0.5494505494505495, MLPClassifier(), 'MedianAbsScaler', 'heart_disease'],
#  [0.7446808510638298, MLPClassifier(), 'MedianAbsScaler', 'hepatitis'],
#  [0.9333333333333333, MLPClassifier(), 'MedianAbsScaler', 'iris'],
#  [0.9185, MLPClassifier(), 'MedianAbsScaler', 'letter_recognition'],
#  [0.8121275849982474,
#   MLPClassifier(),
#   'MedianAbsScaler',
#   'magic_gamma_telescope'],
#  [0.7796610169491526, MLPClassifier(), 'MedianAbsScaler', 'parkinsons'],
#  [0.4339457567804024,
#   MLPClassifier(),
#   'MedianAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.6666666666666666, MLPClassifier(), 'MedianAbsScaler', 'wine'],
#  [0.9590643274853801,
#   MLPClassifier(),
#   'RobustScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9428571428571428,
#   MLPClassifier(),
#   'RobustScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.3168462291870715, MLPClassifier(), 'RobustScaler', 'dry_bean_dataset'],
#  [0.47692307692307695,
#   MLPClassifier(),
#   'RobustScaler',
#   'glass_identification'],
#  [0.5384615384615384, MLPClassifier(), 'RobustScaler', 'heart_disease'],
#  [0.7872340425531915, MLPClassifier(), 'RobustScaler', 'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'RobustScaler', 'iris'],
#  [0.923, MLPClassifier(), 'RobustScaler', 'letter_recognition'],
#  [0.827900455660708, MLPClassifier(), 'RobustScaler', 'magic_gamma_telescope'],
#  [0.847457627118644, MLPClassifier(), 'RobustScaler', 'parkinsons'],
#  [0.752405949256343,
#   MLPClassifier(),
#   'RobustScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9259259259259259, MLPClassifier(), 'RobustScaler', 'wine'],
#  [0.9532163742690059,
#   MLPClassifier(),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9428571428571428,
#   MLPClassifier(),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.19711067580803135,
#   MLPClassifier(),
#   'PowerTransformer',
#   'dry_bean_dataset'],
#  [0.47692307692307695,
#   MLPClassifier(),
#   'PowerTransformer',
#   'glass_identification'],
#  [0.4835164835164835, MLPClassifier(), 'PowerTransformer', 'heart_disease'],
#  [0.7872340425531915, MLPClassifier(), 'PowerTransformer', 'hepatitis'],
#  [0.9777777777777777, MLPClassifier(), 'PowerTransformer', 'iris'],
#  [0.9198333333333333,
#   MLPClassifier(),
#   'PowerTransformer',
#   'letter_recognition'],
#  [0.8333333333333334,
#   MLPClassifier(),
#   'PowerTransformer',
#   'magic_gamma_telescope'],
#  [0.8983050847457628, MLPClassifier(), 'PowerTransformer', 'parkinsons'],
#  [0.6176727909011374,
#   MLPClassifier(),
#   'PowerTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.35185185185185186, MLPClassifier(), 'PowerTransformer', 'wine'],
#  [0.9649122807017544,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.38638589618021546,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'dry_bean_dataset'],
#  [0.47692307692307695,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'glass_identification'],
#  [0.4835164835164835, MLPClassifier(), 'QuantileTransformer', 'heart_disease'],
#  [0.8297872340425532, MLPClassifier(), 'QuantileTransformer', 'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'QuantileTransformer', 'iris'],
#  [0.9223333333333333,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'letter_recognition'],
#  [0.8089730108657553,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'magic_gamma_telescope'],
#  [0.864406779661017, MLPClassifier(), 'QuantileTransformer', 'parkinsons'],
#  [0.7594050743657043,
#   MLPClassifier(),
#   'QuantileTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, MLPClassifier(), 'QuantileTransformer', 'wine'],
#  [0.9415204678362573,
#   MLPClassifier(),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9428571428571428,
#   MLPClassifier(),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.49167482859941236, MLPClassifier(), 'DecimalScaling', 'dry_bean_dataset'],
#  [0.35384615384615387,
#   MLPClassifier(),
#   'DecimalScaling',
#   'glass_identification'],
#  [0.43956043956043955, MLPClassifier(), 'DecimalScaling', 'heart_disease'],
#  [0.8085106382978723, MLPClassifier(), 'DecimalScaling', 'hepatitis'],
#  [0.9333333333333333, MLPClassifier(), 'DecimalScaling', 'iris'],
#  [0.9238333333333333, MLPClassifier(), 'DecimalScaling', 'letter_recognition'],
#  [0.8208902909218366,
#   MLPClassifier(),
#   'DecimalScaling',
#   'magic_gamma_telescope'],
#  [0.8813559322033898, MLPClassifier(), 'DecimalScaling', 'parkinsons'],
#  [0.42957130358705164,
#   MLPClassifier(),
#   'DecimalScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.4074074074074074, MLPClassifier(), 'DecimalScaling', 'wine'],
#  [0.9181286549707602,
#   MLPClassifier(),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9428571428571428,
#   MLPClassifier(),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.5629285014691479, MLPClassifier(), 'TanhTransformer', 'dry_bean_dataset'],
#  [0.6307692307692307,
#   MLPClassifier(),
#   'TanhTransformer',
#   'glass_identification'],
#  [0.4725274725274725, MLPClassifier(), 'TanhTransformer', 'heart_disease'],
#  [0.8723404255319149, MLPClassifier(), 'TanhTransformer', 'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'TanhTransformer', 'iris'],
#  [0.924, MLPClassifier(), 'TanhTransformer', 'letter_recognition'],
#  [0.8450753592709429,
#   MLPClassifier(),
#   'TanhTransformer',
#   'magic_gamma_telescope'],
#  [0.7457627118644068, MLPClassifier(), 'TanhTransformer', 'parkinsons'],
#  [0.6964129483814523,
#   MLPClassifier(),
#   'TanhTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.4074074074074074, MLPClassifier(), 'TanhTransformer', 'wine'],
#  [0.935672514619883,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.44123408423114596,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'dry_bean_dataset'],
#  [0.47692307692307695,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'glass_identification'],
#  [0.5164835164835165,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'heart_disease'],
#  [0.851063829787234,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'LogisticSigmoidTransformer', 'iris'],
#  [0.9218333333333333,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'letter_recognition'],
#  [0.84086926042762,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'magic_gamma_telescope'],
#  [0.8983050847457628,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'parkinsons'],
#  [0.668416447944007,
#   MLPClassifier(),
#   'LogisticSigmoidTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.2222222222222222, MLPClassifier(), 'LogisticSigmoidTransformer', 'wine'],
#  [0.9590643274853801,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9476190476190476,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.5156709108716944,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'dry_bean_dataset'],
#  [0.38461538461538464,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'heart_disease'],
#  [0.8297872340425532,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'hepatitis'],
#  [0.9555555555555556, MLPClassifier(), 'HyperbolicTangentTransformer', 'iris'],
#  [0.9148333333333334,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'letter_recognition'],
#  [0.8321065545040308,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'magic_gamma_telescope'],
#  [0.8813559322033898,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'parkinsons'],
#  [0.6649168853893264,
#   MLPClassifier(),
#   'HyperbolicTangentTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.5370370370370371, MLPClassifier(), 'HyperbolicTangentTransformer', 'wine'],
#  [0.9766081871345029,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9571428571428572,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.925073457394711,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'dry_bean_dataset'],
#  [0.6615384615384615,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'glass_identification'],
#  [0.5714285714285714,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'heart_disease'],
#  [0.7872340425531915, RandomForestClassifier(), 'MinMaxScaler', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'MinMaxScaler', 'iris'],
#  [0.9673333333333334,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'letter_recognition'],
#  [0.8818787241500176,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, RandomForestClassifier(), 'MinMaxScaler', 'parkinsons'],
#  [0.926509186351706,
#   RandomForestClassifier(),
#   'MinMaxScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'MinMaxScaler', 'wine'],
#  [0.9473684210526315,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9571428571428572,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.925073457394711,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'dry_bean_dataset'],
#  [0.6923076923076923,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'glass_identification'],
#  [0.5384615384615384,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'heart_disease'],
#  [0.851063829787234, RandomForestClassifier(), 'MaxAbsScaler', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'MaxAbsScaler', 'iris'],
#  [0.9685, RandomForestClassifier(), 'MaxAbsScaler', 'letter_recognition'],
#  [0.8841570276901507,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, RandomForestClassifier(), 'MaxAbsScaler', 'parkinsons'],
#  [0.9273840769903762,
#   RandomForestClassifier(),
#   'MaxAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'MaxAbsScaler', 'wine'],
#  [0.9590643274853801,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.9255631733594515,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'dry_bean_dataset'],
#  [0.676923076923077,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'glass_identification'],
#  [0.5824175824175825,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'heart_disease'],
#  [0.8085106382978723, RandomForestClassifier(), 'StandardScaler', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'StandardScaler', 'iris'],
#  [0.9656666666666667,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'letter_recognition'],
#  [0.8818787241500176,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'magic_gamma_telescope'],
#  [0.9152542372881356,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'parkinsons'],
#  [0.9256342957130359,
#   RandomForestClassifier(),
#   'StandardScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'StandardScaler', 'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9571428571428572,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.9240940254652301,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'dry_bean_dataset'],
#  [0.6923076923076923,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'glass_identification'],
#  [0.5824175824175825,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'heart_disease'],
#  [0.8085106382978723, RandomForestClassifier(), 'ParetoScaling', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'ParetoScaling', 'iris'],
#  [0.9666666666666667,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'letter_recognition'],
#  [0.8803014370837715,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, RandomForestClassifier(), 'ParetoScaling', 'parkinsons'],
#  [0.9238845144356955,
#   RandomForestClassifier(),
#   'ParetoScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.9629629629629629, RandomForestClassifier(), 'ParetoScaling', 'wine'],
#  [0.9590643274853801,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.9255631733594515,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'dry_bean_dataset'],
#  [0.6615384615384615,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'glass_identification'],
#  [0.5384615384615384,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'heart_disease'],
#  [0.7446808510638298,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'hepatitis'],
#  [0.9777777777777777,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'iris'],
#  [0.9686666666666667,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'letter_recognition'],
#  [0.879074658254469,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'magic_gamma_telescope'],
#  [0.9491525423728814,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'parkinsons'],
#  [0.9291338582677166,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.9629629629629629,
#   RandomForestClassifier(),
#   'StandardStabilityScaling',
#   'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9571428571428572,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'breast_cancer_wisconsin_original'],
#  [0.9240940254652301,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'dry_bean_dataset'],
#  [0.6923076923076923,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'glass_identification'],
#  [0.5604395604395604,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'heart_disease'],
#  [0.7659574468085106, RandomForestClassifier(), 'MeanCentered', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'MeanCentered', 'iris'],
#  [0.9675, RandomForestClassifier(), 'MeanCentered', 'letter_recognition'],
#  [0.8794251664914126,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, RandomForestClassifier(), 'MeanCentered', 'parkinsons'],
#  [0.9256342957130359,
#   RandomForestClassifier(),
#   'MeanCentered',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'MeanCentered', 'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.92384916748286,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'dry_bean_dataset'],
#  [0.6923076923076923,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'glass_identification'],
#  [0.5384615384615384,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'heart_disease'],
#  [0.8297872340425532,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'MedianAbsScaler', 'iris'],
#  [0.967, RandomForestClassifier(), 'MedianAbsScaler', 'letter_recognition'],
#  [0.881528215913074,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'parkinsons'],
#  [0.9273840769903762,
#   RandomForestClassifier(),
#   'MedianAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'MedianAbsScaler', 'wine'],
#  [0.9707602339181286,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9571428571428572,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.922869735553379,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'dry_bean_dataset'],
#  [0.676923076923077,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'glass_identification'],
#  [0.5824175824175825,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'heart_disease'],
#  [0.8297872340425532, RandomForestClassifier(), 'RobustScaler', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'RobustScaler', 'iris'],
#  [0.9661666666666666,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'letter_recognition'],
#  [0.88310550297932,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, RandomForestClassifier(), 'RobustScaler', 'parkinsons'],
#  [0.9256342957130359,
#   RandomForestClassifier(),
#   'RobustScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'RobustScaler', 'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9571428571428572,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9265426052889324,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'dry_bean_dataset'],
#  [0.676923076923077,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'glass_identification'],
#  [0.5604395604395604,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'heart_disease'],
#  [0.7872340425531915,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'PowerTransformer', 'iris'],
#  [0.9641666666666666,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'letter_recognition'],
#  [0.8808271994391869,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'magic_gamma_telescope'],
#  [0.9152542372881356,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'parkinsons'],
#  [0.9221347331583553,
#   RandomForestClassifier(),
#   'PowerTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9629629629629629, RandomForestClassifier(), 'PowerTransformer', 'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9428571428571428,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9240940254652301,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'dry_bean_dataset'],
#  [0.6615384615384615,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'glass_identification'],
#  [0.5604395604395604,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'heart_disease'],
#  [0.7872340425531915,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'QuantileTransformer', 'iris'],
#  [0.9656666666666667,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'letter_recognition'],
#  [0.8836312653347353,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'magic_gamma_telescope'],
#  [0.9152542372881356,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'parkinsons'],
#  [0.9256342957130359,
#   RandomForestClassifier(),
#   'QuantileTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9629629629629629, RandomForestClassifier(), 'QuantileTransformer', 'wine'],
#  [0.9590643274853801,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.9243388834476004,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'dry_bean_dataset'],
#  [0.7076923076923077,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'glass_identification'],
#  [0.5934065934065934,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'heart_disease'],
#  [0.7659574468085106, RandomForestClassifier(), 'DecimalScaling', 'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'DecimalScaling', 'iris'],
#  [0.9645, RandomForestClassifier(), 'DecimalScaling', 'letter_recognition'],
#  [0.8843322818086226,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'parkinsons'],
#  [0.9238845144356955,
#   RandomForestClassifier(),
#   'DecimalScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815, RandomForestClassifier(), 'DecimalScaling', 'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9236043095004897,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'dry_bean_dataset'],
#  [0.6923076923076923,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'glass_identification'],
#  [0.5384615384615384,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'heart_disease'],
#  [0.7659574468085106,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'hepatitis'],
#  [0.9777777777777777, RandomForestClassifier(), 'TanhTransformer', 'iris'],
#  [0.968, RandomForestClassifier(), 'TanhTransformer', 'letter_recognition'],
#  [0.8810024535576586,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'parkinsons'],
#  [0.9230096237970253,
#   RandomForestClassifier(),
#   'TanhTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9629629629629629, RandomForestClassifier(), 'TanhTransformer', 'wine'],
#  [0.9649122807017544,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9260528893241919,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'dry_bean_dataset'],
#  [0.6923076923076923,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'glass_identification'],
#  [0.5714285714285714,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'heart_disease'],
#  [0.8085106382978723,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'hepatitis'],
#  [0.9777777777777777,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'iris'],
#  [0.968,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'letter_recognition'],
#  [0.8834560112162636,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'parkinsons'],
#  [0.9282589676290464,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815,
#   RandomForestClassifier(),
#   'LogisticSigmoidTransformer',
#   'wine'],
#  [0.9532163742690059,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9523809523809523,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.9267874632713027,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'dry_bean_dataset'],
#  [0.6615384615384615,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'glass_identification'],
#  [0.5494505494505495,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'heart_disease'],
#  [0.7659574468085106,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'hepatitis'],
#  [0.9777777777777777,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'iris'],
#  [0.9665,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'letter_recognition'],
#  [0.8801261829652997,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'parkinsons'],
#  [0.9238845144356955,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9814814814814815,
#   RandomForestClassifier(),
#   'HyperbolicTangentTransformer',
#   'wine'],
#  [0.9239766081871345,
#   GaussianNB(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   GaussianNB(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.7659157688540646, GaussianNB(), 'MinMaxScaler', 'dry_bean_dataset'],
#  [0.46153846153846156, GaussianNB(), 'MinMaxScaler', 'glass_identification'],
#  [0.45054945054945056, GaussianNB(), 'MinMaxScaler', 'heart_disease'],
#  [0.7021276595744681, GaussianNB(), 'MinMaxScaler', 'hepatitis'],
#  [1.0, GaussianNB(), 'MinMaxScaler', 'iris'],
#  [0.6496666666666666, GaussianNB(), 'MinMaxScaler', 'letter_recognition'],
#  [0.7245005257623555, GaussianNB(), 'MinMaxScaler', 'magic_gamma_telescope'],
#  [0.6779661016949152, GaussianNB(), 'MinMaxScaler', 'parkinsons'],
#  [0.9186351706036745,
#   GaussianNB(),
#   'MinMaxScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9444444444444444, GaussianNB(), 'MinMaxScaler', 'wine'],
#  [0.9239766081871345,
#   GaussianNB(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   GaussianNB(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.7659157688540646, GaussianNB(), 'MaxAbsScaler', 'dry_bean_dataset'],
#  [0.46153846153846156, GaussianNB(), 'MaxAbsScaler', 'glass_identification'],
#  [0.45054945054945056, GaussianNB(), 'MaxAbsScaler', 'heart_disease'],
#  [0.7021276595744681, GaussianNB(), 'MaxAbsScaler', 'hepatitis'],
#  [1.0, GaussianNB(), 'MaxAbsScaler', 'iris'],
#  [0.6496666666666666, GaussianNB(), 'MaxAbsScaler', 'letter_recognition'],
#  [0.7245005257623555, GaussianNB(), 'MaxAbsScaler', 'magic_gamma_telescope'],
#  [0.6779661016949152, GaussianNB(), 'MaxAbsScaler', 'parkinsons'],
#  [0.9186351706036745,
#   GaussianNB(),
#   'MaxAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.9444444444444444, GaussianNB(), 'MaxAbsScaler', 'wine'],
#  [0.9239766081871345,
#   GaussianNB(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   GaussianNB(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.7659157688540646, GaussianNB(), 'StandardScaler', 'dry_bean_dataset'],
#  [0.46153846153846156, GaussianNB(), 'StandardScaler', 'glass_identification'],
#  [0.45054945054945056, GaussianNB(), 'StandardScaler', 'heart_disease'],
#  [0.7021276595744681, GaussianNB(), 'StandardScaler', 'hepatitis'],
#  [1.0, GaussianNB(), 'StandardScaler', 'iris'],
#  [0.6496666666666666, GaussianNB(), 'StandardScaler', 'letter_recognition'],
#  [0.7245005257623555, GaussianNB(), 'StandardScaler', 'magic_gamma_telescope'],
#  [0.6779661016949152, GaussianNB(), 'StandardScaler', 'parkinsons'],
#  [0.9186351706036745,
#   GaussianNB(),
#   'StandardScaler',
#   'rice_cammeo_and_osmancik'],
# ...
#  [0.8135296179460217,
#   DecisionTreeClassifier(),
#   'LogisticSigmoidTransformer',
#   'magic_gamma_telescope'],
#  [0.8813559322033898,
#   DecisionTreeClassifier(),
#   'LogisticSigmoidTransformer',
#   'parkinsons'],
#  [0.8862642169728784,
#   DecisionTreeClassifier(),
#   'LogisticSigmoidTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9629629629629629,
#   DecisionTreeClassifier(),
#   'LogisticSigmoidTransformer',
#   'wine'],
#  [0.9239766081871345,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.8986287952987267,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'dry_bean_dataset'],
#  [0.6153846153846154,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'glass_identification'],
#  [0.5494505494505495,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'heart_disease'],
#  [0.7446808510638298,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'hepatitis'],
#  [0.9777777777777777,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'iris'],
#  [0.8736666666666667,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'letter_recognition'],
#  [0.8107255520504731,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'parkinsons'],
#  [0.8915135608048994,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.9444444444444444,
#   DecisionTreeClassifier(),
#   'HyperbolicTangentTransformer',
#   'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'MinMaxScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'MinMaxScaler',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'MinMaxScaler',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'MinMaxScaler', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'MinMaxScaler', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'MinMaxScaler', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'MinMaxScaler', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'MinMaxScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'MinMaxScaler', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'MinMaxScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'MinMaxScaler', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'MaxAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'MaxAbsScaler',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'MaxAbsScaler',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'MaxAbsScaler', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'MaxAbsScaler', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'MaxAbsScaler', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'MaxAbsScaler', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'MaxAbsScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'MaxAbsScaler', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'MaxAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'MaxAbsScaler', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'StandardScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'StandardScaler',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'StandardScaler',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'StandardScaler', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'StandardScaler', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'StandardScaler', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'StandardScaler', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'StandardScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'StandardScaler', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'StandardScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'StandardScaler', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'ParetoScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'ParetoScaling',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'ParetoScaling',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'ParetoScaling', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'ParetoScaling', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'ParetoScaling', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'ParetoScaling', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'ParetoScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'ParetoScaling', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'ParetoScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'ParetoScaling', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'glass_identification'],
#  [0.5164835164835165,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'heart_disease'],
#  [0.8723404255319149,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'hepatitis'],
#  [0.9111111111111111,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'iris'],
#  [0.3175,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888,
#   AdaBoostClassifier(),
#   'StandardStabilityScaling',
#   'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'MeanCentered',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'MeanCentered',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'MeanCentered',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'MeanCentered',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'MeanCentered', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'MeanCentered', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'MeanCentered', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'MeanCentered', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'MeanCentered',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'MeanCentered', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'MeanCentered',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'MeanCentered', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'glass_identification'],
#  [0.5164835164835165,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'MedianAbsScaler', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'MedianAbsScaler', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'MedianAbsScaler', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'MedianAbsScaler', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'MedianAbsScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'MedianAbsScaler', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'RobustScaler',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'RobustScaler',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'RobustScaler',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'RobustScaler',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'RobustScaler', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'RobustScaler', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'RobustScaler', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'RobustScaler', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'RobustScaler',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'RobustScaler', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'RobustScaler',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'RobustScaler', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'glass_identification'],
#  [0.5164835164835165,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'PowerTransformer', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'PowerTransformer', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'PowerTransformer', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'PowerTransformer', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'PowerTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'PowerTransformer', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'glass_identification'],
#  [0.5164835164835165,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'heart_disease'],
#  [0.8723404255319149,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'QuantileTransformer', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'QuantileTransformer', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'QuantileTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'QuantileTransformer', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'DecimalScaling',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'DecimalScaling',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'DecimalScaling',
#   'glass_identification'],
#  [0.5164835164835165, AdaBoostClassifier(), 'DecimalScaling', 'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'DecimalScaling', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'DecimalScaling', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'DecimalScaling', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'DecimalScaling',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'DecimalScaling', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'DecimalScaling',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'DecimalScaling', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'glass_identification'],
#  [0.5164835164835165,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'heart_disease'],
#  [0.8723404255319149, AdaBoostClassifier(), 'TanhTransformer', 'hepatitis'],
#  [0.9111111111111111, AdaBoostClassifier(), 'TanhTransformer', 'iris'],
#  [0.3175, AdaBoostClassifier(), 'TanhTransformer', 'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084, AdaBoostClassifier(), 'TanhTransformer', 'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'TanhTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888, AdaBoostClassifier(), 'TanhTransformer', 'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'glass_identification'],
#  [0.5164835164835165,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'heart_disease'],
#  [0.8723404255319149,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'hepatitis'],
#  [0.9111111111111111,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'iris'],
#  [0.3175,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'letter_recognition'],
#  [0.8371889239397126,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'magic_gamma_telescope'],
#  [0.9322033898305084,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'parkinsons'],
#  [0.9282589676290464,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'rice_cammeo_and_osmancik'],
#  [0.8888888888888888,
#   AdaBoostClassifier(),
#   'LogisticSigmoidTransformer',
#   'wine'],
#  [0.9649122807017544,
#   AdaBoostClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_diagnostic'],
#  [0.9380952380952381,
#   AdaBoostClassifier(),
#   'HyperbolicTangentTransformer',
#   'breast_cancer_wisconsin_original'],
#  [0.6581782566111655,
#   AdaBoostClassifier(),
#   'HyperbolicTangentTransformer',
#   'dry_bean_dataset'],
#  [0.49230769230769234,
#   AdaBoostClassifier(),
#   'HyperbolicTangentTransformer',
#   'glass_identification'],
#  ...]
